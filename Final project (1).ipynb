# %% [markdown]
# # Final project

# %% [markdown]
# ## f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# *1.Определить корни*
#
# *2.Найти интервалы, на которых функция возрастает*
#
# *3.Найти интервалы, на которых функция убывает*
#
# *4.Построить график*
#
# *5.Вычислить вершину*
#
# *6.Определить промежутки, на котором f > 0*
#
# *7.Определить промежутки, на котором f < 0*

# %%
from sympy import *
from sympy.plotting import plot
from matplotlib import *
init_printing()
x = Symbol('x')
f = -12*x*x*x*x* sin(cos(x)) - 18*x*x*x + 5*x*x + 10*x - 30
plot(f,(x,-50,50), line_color = 'red',title = 'График функции f')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Корни уравнения

# %%
print(f'Корни уравнения равны: {solveset(Eq(f,0),x)}')
# Out:
# Корни уравнения равны: ConditionSet(x, Eq(-12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30, 0), Complexes)

# %% [markdown]
# ## Возрастание и убывание функции

# %%
df = f.diff(x)
print('На участках, где: \n(df < 0) - функция убывает, \n(df > 0) - функция возрастает')
plot(df,(x, -20, 20), line_color ='blue', title = 'График функции df')
plot(f,(x, -20, 20),line_color ='green', title = 'График функции f')
# Out:
# На участках, где:
# (df < 0) - функция убывает,
# (df > 0) - функция возрастает
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Производная, точка пересечения и минимальное значение функции ##

# %%
print(f'Производная: {df}')
# Out:
# Производная: 12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10

# %%
print(f'Точка пересечения с осью Y: [0, {f.subs(x,0)}]')
print(f'Функция f(x) = {f} имеет множество корней и не имеет экстремумов')
# Out:
# Точка пересечения с осью Y: [0, -30]
# Функция f(x) = -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30 имеет множество корней и не имеет экстремумов
